# %%
# 1. Remove Duplicates from a List
nums=[1,2,2,3,4,4,5]
unique=set(nums)
print(unique)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 5. Find Common Subjects
s1={"maths","physics","chemistry"}
s2={"biology","physics","maths"}
common=s1&s2
print(common)
# Out:
# {'physics', 'maths'}

# %%
# 6.Add and Remove Elements in a Set
colors={"red","blue","green"}
colors.add("yellow")
colors.remove("blue")
print(colors)
# Out:
# {'yellow', 'green', 'red'}
