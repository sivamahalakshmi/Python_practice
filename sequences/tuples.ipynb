# %%
#1.Create a tuple with details of a student — name, age, and grade. Print each value using indexing.
t=("maha", "20", "A")
for i in range(len(t)):
    print(i,t[i])
# Out:
# 0 maha
# 1 20
# 2 A

# %%
#2. Smallest and Largest NumberWrite a program to find the smallest and largest number in a tuple of integers.
t=(10, 25, 3, 78, 45)
print("Smallest:", min(t))
print("Largest:", max(t))
# Out:
# Smallest: 3
# Largest: 78

# %%
#3.Count Element Occurrence
fruits=("apple","banana","apple","orange","apple","grape")
count=fruits.count("apple")
print("Apple appears",count,"times")
# Out:
# Apple appears 3 times
