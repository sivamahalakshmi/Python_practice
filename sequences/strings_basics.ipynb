# %%
#1. Length of a String
s=input()
print(len(s))
# Out:
# 4

# %%
#2. Convert String to Uppercase and Lowercase
s=input()
print(s.lower())
print(s.upper())
# Out:
# maha
# MAHA

# %%
#3. Compare Two Strings
s1=input()
s2=input()
if s1==s2:
    print("equal")
else:
    print("not equal")
# Out:
# equal

# %%
s1=input()
s2=input()
if s1.casefold()==s2.casefold():
    print("equal")
else:
    print("not equal")
# Out:
# equal

# %%
s1=input().lower()
s2=input().lower()
if s1==s2:
    print("equal")
else:
    print("not equal")
# Out:
# equal

# %%
#4. Concatenate Two Strings
s1=input()
s2=input()
s3=s1+" "+s2
print(s3)
# Out:
# hello world

# %%
#5. Reverse a String
s=input()
rev=s[::-1]
print(rev)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3 rev=s[::-1]
#       4 #print(rev)
# ----> 5 rev2=s.reverse()
#       6 print(rev2)
#
# AttributeError: 'str' object has no attribute 'reverse'

# %%
#6. Check Palindrome String
s=input()
if s==s[::-1]:
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# palindrome

# %%
#7. Count Vowels in a String
s=input()
c=0
for i in s:
    if i in "aeiouAEIOU":
        c+=1
print(c)
# Out:
# 2

# %%
#8. Find Character at Given Index
s=input()
c=input()
for i in range(len(s)):
    if c==s[i]:
        print(i+1)
        break
# Out:
# 3

# %%
s=input()
c=input()
print(s.index(c)+1)
# Out:
# 3

# %%
#9. Check if String Contains a Substring
s=input()
s2=input()
if s2 in s:
    print("substring found")
else:
    print("substring not found")
# Out:
# substring found

# %%
#10. Replace Character in String
s=input() #banana
print(s.replace("a","o",2)) #2-represents the number of replacements from left to right
#output: bonona
# Out:
# bonona

# %%
#11. Remove Spaces from a String
s=input()
print(s.replace(" ",""))
# Out:
# helloworld

# %%
#12. Split a String into Words
s=input()
s2=s.split(',')
print(s2)
# Out:
# ['hello', 'world']

# %%
# s=input("enter 3 numbers").split()
# sum=0
# for i in s:
#     sum+=int(i)
# print(sum)

n=input().split()
s=list(map(int,n))
tot=0
print(sum(s))
# Out:
# 60

# %%
del sum
l=[2,3,4,5]
print(sum(l))
# Out:
# 14

# %%
#13. Count Words in a String
# Input: Enter a string: Java is very powerful
# Output: Number of words: 4 Hint: Split using space and count
s=input().split()
print(len(s))
# Out:
# 4

# %%
# 14. Check Starting and Ending Character
# Input: Enter a string: programming
# Output: Starts with p, Ends with g Hint: Use startsWith() and endsWith()
s=input()
if s.startswith("p") and s.endswith("g"):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
# 15. Convert String to Integer
# Input: Enter a string number: 123
# Output: Integer value: 123 Hint: Use Integer.parseInt()
s=input()
i=int(s)
print("integer value:",i)
# Out:
# integer value: 1234
