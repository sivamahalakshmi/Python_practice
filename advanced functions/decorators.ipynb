# %%
def add_finite_nos(add):
    def add_wrapper(*a):
        print("Input values:",a)
        print(type(a))
        ans=add(*a)
        print("Output value:",ans)
    return add_wrapper
@add_finite_nos
def add(*a):
    s=0
    print(a)
    for i in a:
        s+=i
    return s
add(1,4,6,3)
# Out:
# Input values: (1, 4, 6, 3)
# <class 'tuple'>
# (1, 4, 6, 3)
# Output value: 14
